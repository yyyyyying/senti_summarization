# %%
# encoding=utf-8
import jieba
from gensim.corpora import Dictionary
from gensim.models import LdaModel
from gensim.models import ldaseqmodel
stopwords = [line.strip() for line in open('./chinese_stopword.txt','r').readlines()]

# %%
train=[]
time_slice=[]
f= open('../dtm/jg_wb','r')
info=eval(f.readline().strip()) 

for i in info:
    time_slice.append(i[1][0])

line=eval(f.readline().strip()) 

for i in f.readlines():
    i=eval(i.strip())
    train.append(i[3])

# %%
jieba.add_word(u'江歌') 
jieba.add_word(u'江歌案') 
jieba.add_word(u'江秋莲')
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /var/folders/zl/mq8nkx1d61j593pcb674_sbc0000gn/T/jieba.cache
# Loading model cost 1.034 seconds.
# Prefix dict has been built succesfully.

# %%
train_set = []
for line in train:
    line = list(jieba.cut(line))
    train_set.append([ w for w in line if w not in stopwords and len(w)>1 ]) #不是听用词 且 长度>1（去除单个字）

# %%
len(train)
# Out:
# 368037

# %%
time_slice

# %%
dictionary = Dictionary(train_set)
corpus = [ dictionary.doc2bow(text) for text in train_set]

# %%
#主题数设置问题
ldaseq = ldaseqmodel.LdaSeqModel(corpus=corpus, id2word=dictionary, time_slice=time_slice, num_topics=5)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/ldaseqmodel.py:1043: RuntimeWarning: invalid value encountered in double_scalars
#   converged = np.fabs((lhood_old - lhood) / (lhood_old * total))

# %%
#某个时间的主题分布
print('ldaseq_topic----------\n',ldaseq.print_topics(time=0))
# Out:
# ldaseq_topic----------
#  [[('扎克', 0.04070981551260958), ('伯格', 0.04070958952362302), (' ', 0.04047721811407496), ('文件', 0.024043969974825385), ('数据', 0.024043969974825385), ('公司', 0.023895399033061426), ('沟通', 0.023895399033061426), ('时间', 0.023768740828785537), ('下午', 0.023768715145565632), ('东部', 0.023768715145565632), ('美国', 0.023768715145565632), ('听证会', 0.010381782526022398), ('摄影师', 0.010379281752237398), ('副总裁', 0.0103694965095012), ('Facebook', 0.0103694965095012), ('负责', 0.0103694965095012), ('拍摄', 0.0103694965095012), ('LDA', 0.008003655651853639), ('现场', 0.006884435440317999), ('媒体', 0.0068765144751385295)], [('语料', 0.06350357662887952), ('听证会', 0.046668146563114875), ('小时', 0.046610659132384054), ('伯格', 0.01952208457957861), ('扎克', 0.019518727332265673), ('现场', 0.019517131228680113), ('LDA', 0.014413488610690703), ('停止', 0.011707544125121011), ('这场', 0.01170745087095029), ('不到', 0.011706822754925678), ('train', 0.011706411499056197), ('分词', 0.011706301634651643), ('抵达', 0.011706129168248465), ('今天下午', 0.011705570591928931), ('将会', 0.011705234913027263), ('最多', 0.0117048332974856), ('实录', 0.011704754487235918), ('半个', 0.01170455754959641), ('训练', 0.011704288420441427), ('包括', 0.01170419199114415)]]

# %%
#某个主题各个时间的分布
print('ldaseq_topic_times----------\n',ldaseq.print_topic_times(topic=0))
# Out:
# ldaseq_topic_times----------
#  [[('扎克', 0.04070981551260958), ('伯格', 0.04070958952362302), (' ', 0.04047721811407496), ('文件', 0.024043969974825385), ('数据', 0.024043969974825385), ('公司', 0.023895399033061426), ('沟通', 0.023895399033061426), ('时间', 0.023768740828785537), ('下午', 0.023768715145565632), ('东部', 0.023768715145565632), ('美国', 0.023768715145565632), ('听证会', 0.010381782526022398), ('摄影师', 0.010379281752237398), ('副总裁', 0.0103694965095012), ('Facebook', 0.0103694965095012), ('负责', 0.0103694965095012), ('拍摄', 0.0